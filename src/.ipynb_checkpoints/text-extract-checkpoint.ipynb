# %%
pip install --upgrade pymupdf
# Out:
# Collecting pymupdf
#   Downloading PyMuPDF-1.23.6-cp38-none-manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 3.2 MB/s eta 0:00:01
# Collecting PyMuPDFb==1.23.6
#   Downloading PyMuPDFb-1.23.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      |████████████████████████████████| 30.6 MB 5.3 MB/s eta 0:00:01
# Installing collected packages: PyMuPDFb, pymupdf
#   Attempting uninstall: PyMuPDFb
#     Found existing installation: PyMuPDFb 1.23.5
#     Uninstalling PyMuPDFb-1.23.5:
#       Successfully uninstalled PyMuPDFb-1.23.5
#   Attempting uninstall: pymupdf
#     Found existing installation: PyMuPDF 1.23.5
#     Uninstalling PyMuPDF-1.23.5:
#       Successfully uninstalled PyMuPDF-1.23.5
# Successfully installed PyMuPDFb-1.23.6 pymupdf-1.23.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz

# %%
doc = fitz.open("../resources/testpdf/test1.pdf", filetype="pdf")

# %%
doc.page_count
# Out:
# 1

# %%
import json
#f = open('test.html', 'w') 

pages_json = {}

pages = doc.pages()
for page in pages:
    # https://pymupdf.readthedocs.io/en/latest/page.html#Page.get_text
    page_cropbox = page.cropbox
    page_info = page.get_text("rawjson")
    page_json = json.loads(page_info)
    pages_json[page.number] = page_json

# blocks of page 1
print(pages_json[0]['blocks'])
# Out:
# [{'number': 0, 'type': 0, 'bbox': [56.79999923706055, 57.2073974609375, 95.5960922241211, 70.4964599609375], 'lines': [{'spans': [{'size': 12.0, 'flags': 4, 'font': 'LiberationSerif', 'color': 0, 'ascender': 0.89111328125, 'descender': -0.21630859375, 'chars': [{'origin': [56.79999923706055, 67.9007568359375], 'bbox': [56.79999923706055, 57.2073974609375, 64.13008117675781, 70.4964599609375], 'c': 'T'}, {'origin': [63.30400085449219, 67.9007568359375], 'bbox': [63.30400085449219, 57.2073974609375, 68.63017272949219, 70.4964599609375], 'c': 'e'}, {'origin': [68.60800170898438, 67.9007568359375], 'bbox': [68.60800170898438, 57.2073974609375, 73.27792358398438, 70.4964599609375], 'c': 's'}, {'origin': [73.30000305175781, 67.9007568359375], 'bbox': [73.30000305175781, 57.2073974609375, 76.63398742675781, 70.4964599609375], 'c': 't'}, {'origin': [76.5999984741211, 67.9007568359375], 'bbox': [76.5999984741211, 57.2073974609375, 79.5999984741211, 70.4964599609375], 'c': ' '}, {'origin': [79.5999984741211, 67.9007568359375], 'bbox': [79.5999984741211, 57.2073974609375, 85.5999984741211, 70.4964599609375], 'c': 'p'}, {'origin': [85.5999984741211, 67.9007568359375], 'bbox': [85.5999984741211, 57.2073974609375, 91.5999984741211, 70.4964599609375], 'c': 'd'}, {'origin': [91.5999984741211, 67.9007568359375], 'bbox': [91.5999984741211, 57.2073974609375, 95.5960922241211, 70.4964599609375], 'c': 'f'}], 'origin': [56.79999923706055, 67.9007568359375], 'bbox': [56.79999923706055, 57.2073974609375, 95.5960922241211, 70.4964599609375]}], 'wmode': 0, 'dir': [1.0, 0.0], 'bbox': [56.79999923706055, 57.2073974609375, 95.5960922241211, 70.4964599609375]}]}, {'number': 1, 'type': 0, 'bbox': [56.79999923706055, 84.80743408203125, 134.4019775390625, 98.09649658203125], 'lines': [{'spans': [{'size': 12.0, 'flags': 4, 'font': 'LiberationSerif', 'color': 0, 'ascender': 0.89111328125, 'descender': -0.21630859375, 'chars': [{'origin': [56.79999923706055, 95.50079345703125], 'bbox': [56.79999923706055, 84.80743408203125, 60.13398361206055, 98.09649658203125], 'c': 't'}, {'origin': [60.10000228881836, 95.50079345703125], 'bbox': [60.10000228881836, 84.80743408203125, 66.10000610351562, 98.09649658203125], 'c': 'h'}, {'origin': [66.10000610351562, 95.50079345703125], 'bbox': [66.10000610351562, 84.80743408203125, 69.43399047851562, 98.09649658203125], 'c': 'i'}, {'origin': [69.4000015258789, 95.50079345703125], 'bbox': [69.4000015258789, 84.80743408203125, 74.0699234008789, 98.09649658203125], 'c': 's'}, {'origin': [74.09200286865234, 95.50079345703125], 'bbox': [74.09200286865234, 84.80743408203125, 77.09200286865234, 98.09649658203125], 'c': ' '}, {'origin': [77.09200286865234, 95.50079345703125], 'bbox': [77.09200286865234, 84.80743408203125, 80.42598724365234, 98.09649658203125], 'c': 'i'}, {'origin': [80.39199829101562, 95.50079345703125], 'bbox': [80.39199829101562, 84.80743408203125, 85.06192016601562, 98.09649658203125], 'c': 's'}, {'origin': [85.08399963378906, 95.50079345703125], 'bbox': [85.08399963378906, 84.80743408203125, 88.08399963378906, 98.09649658203125], 'c': ' '}, {'origin': [88.08399963378906, 95.50079345703125], 'bbox': [88.08399963378906, 84.80743408203125, 92.75392150878906, 98.09649658203125], 'c': 's'}, {'origin': [92.7760009765625, 95.50079345703125], 'bbox': [92.7760009765625, 84.80743408203125, 98.7760009765625, 98.09649658203125], 'c': 'o'}, {'origin': [98.7760009765625, 95.50079345703125], 'bbox': [98.7760009765625, 84.80743408203125, 108.1099853515625, 98.09649658203125], 'c': 'm'}, {'origin': [108.07599639892578, 95.50079345703125], 'bbox': [108.07599639892578, 84.80743408203125, 113.40216827392578, 98.09649658203125], 'c': 'e'}, {'origin': [113.37999725341797, 95.50079345703125], 'bbox': [113.37999725341797, 84.80743408203125, 116.37999725341797, 98.09649658203125], 'c': ' '}, {'origin': [116.37999725341797, 95.50079345703125], 'bbox': [116.37999725341797, 84.80743408203125, 119.71398162841797, 98.09649658203125], 'c': 't'}, { ...

# %%
"""
search for 'PDF' text on a page and do some tests
"""
doc.save("test1_test.pdf", garbage=3, deflate=True)
doc2 = fitz.open("test1_test.pdf", filetype="pdf")

pages = doc2.pages()
for page in pages:
    
    # Dit is de methode van tekst selecteren, of dat nou een text input field is 
    # of het een manier is om text de selecteren in een GUI
    res = page.search_for('pdf')
    
    # get Rect of text, including the bounding box of text.
    print(res)
    
    # test to extract text using rect
    res2 = page.get_text(clip=res[0])
    print(res2)
    
    # Make Quad of Rect
    res_quad = res[0].quad
    print(res_quad)
    
    # add Redact annotation to select text to be redacted
    redaction = page.add_redact_annot(res_quad, cross_out=False)
    
    doc2.save("test1_annot.pdf", garbage=3, deflate=True)
    
    page.apply_redactions()
    

doc2.save("test1_res.pdf", garbage=3, deflate=True)
# Out:
# [Rect(79.5999984741211, 57.2073974609375, 95.5960922241211, 70.4964599609375)]
# pdf
#
# Quad(Point(79.5999984741211, 57.2073974609375), Point(95.5960922241211, 57.2073974609375), Point(79.5999984741211, 70.4964599609375), Point(95.5960922241211, 70.4964599609375))

# %%
doc_object = {}
xreflen = doc2.xref_length()  # length of objects table
print(xreflen)
for xref in range(1, xreflen):  # skip item 0!
        print("")
        print("object %i (stream: %s)" % (xref, doc2.xref_is_stream(xref)))
        print(doc2.xref_object(xref, compressed=False))
        
        keys = doc2.xref_get_keys(xref)
        object_keys = {}
        for key in keys:
            value = doc2.xref_get_key(xref, key)
            object_keys[key] = value
        if stream := doc2.xref_stream(xref):
                print(stream)
                object_keys["stream"] = stream
            
        doc_object["object%i" % (xref)] = object_keys
# Out:
# 14
#
# object 1 (stream: False)
# <<
#   /Type /Page
#   /Parent 3 0 R
#   /Resources <<
#     /Font <<
#       /F1 7 0 R
#       /Courier 12 0 R
#     >>
#   >>
#   /MediaBox [ 0 0 595.30398 841.8898 ]
#   /Group <<
#     /S /Transparency
#     /CS /DeviceRGB
#     /I true
#   >>
#   /Contents [ 2 0 R 13 0 R ]
#   /Annots [ ]
# >>
#
# object 2 (stream: True)
# <<
#   /Length 253
# >>
# b'q\nq\n.1 w\n0 .028 595.275 841.861 re\nW*\nn\nq\n0 0 0 rg\nBT\n/F1 12 Tf\n56.8 773.989 Td\n[<01>68<02>1<03>-2<04>2<05>] TJ\nET\nQ\nq\n0 0 0 rg\nBT\n/F1 12 Tf\n56.8 746.389 Td\n[<04>2(\\t\\n)2<03>-2<050A>2<03>-2<0503>-2<0B0C>2<02>1<0504>2<02>1(\\r)-7.0000007<04>] TJ\nET\nQ\nQ\nQ\n'
#
# object 3 (stream: False)
# <<
#   /Type /Pages
#   /Resources 9 0 R
#   /MediaBox [ 0 0 595 841 ]
#   /Kids [ 1 0 R ]
#   /Count 1
# >>
#
# object 4 (stream: True)
# <<
#   /Length 6299
#   /Filter /FlateDecode
#   /Length1 10776
# >>
# b'true\x00\x0c\x00\x80\x00\x03\x00@cmap/\x19\x16\x12\x00\x00\x00\xcc\x00\x00\x01\x12cvt =O\x15;\x00\x00\x01\xe0\x00\x00\x02\xd2fpgm\x9a\xb7\\\xf4\x00\x00\x04\xb4\x00\x00\x07\xb4glyf\xd6p\xc2\x07\x00\x00\x0ch\x00\x00\r\xb8headT0\x91-\x00\x00\x1a \x00\x00\x006hheaT\xfey\x07\x00\x00\x1aX\x00\x00\x00$hmtxQ\x03\x1b2\x00\x00\x1a|\x00\x00\x008loca\xea\x154\x13\x00\x00\x1a\xb4\x00\x00\x00\x1emaxp*\x04C\x02\x00\x00\x1a\xd4\x00\x00\x00 name\xf8\x94\xc3d\x00\x00\x1a\xf4\x00\x00\x0bspostd\x00\x88\xff\x00\x00&h\x00\x00\x00 prepL\x9ab\xc5\x00\x00&\x88\x00\x00\x03\x90\x00\x00\x00\x01\x00\x01\x00\x00\x00\x00\x00\x0c\x00\x00\x01\x06\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\rH\x05=\x00\x0f\x00p\x05=\x00\x0f\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\xac\x00\x19\x00\x99\x00\x00\xff\xec\x00\x00\x00\x00\xff\xec\x00\x00\x00\x00\xff\xec\x00\x00\xfeL]\x00\x00\x00\x00\x00\x00\x00F\x00P\x00i\x00u\x00\xd9\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xc1\x00\xd1\x00i\x00\x00\x00\x00\x00P\x00Z\x00\xaa\x00\x8a\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xac\x00\xb8\x00Z\x00\x00\x00\x00\x00P\x00`\x00\x8f\x00\x99\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00P\x00\x97\x00\xb3\x00\xc7\x00\xd9\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00P\x00m\x00{\x00\x8d\x00\xb5\x00\xd9\x011\x00\xc9\x00\x00\x01o\x00\xf2\x01\x08\x00\x81\x00\xc5\x00\xb8\x00\xf2\x011\x00M\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x0e\x00\x00\x00f\x00\x00\x00\x00\x00f\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xdb\x00\x9b\x02\x8b\x00J\x02\xe4\x00\x00\x00\x99\x00f\x00\x00\x02/\x02\x10\x00\xc4\x00\x9c\x01^\x00\x00\x01t\x00F\x00\x8d\x00\x00\x00\x00\x00\x00\x00F\x00<\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x87\x00}\x00\x00\x00S\x00h\x00v\x00\x87\x00\x00\x00\x00\x00\x00\x05=\xfc\xda\x00\t\xff\xf3\x00\x8f\x00}\x00J\x00\x82\x00A\x00l\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xbc\x01\x9f\x03\n\x00\x00\x03T\x00\x9f\x00\xa6\x00\xc1\x00\x00\x00\x00\x00/\x00\x00\x00\x00\x00\x00\x00\x00\x07H\x03j\x02\xb6\x02\x02\xfd\x93\x00\x00\x00\x91\x00g\x00\x91\x00a\x01\xd9\x00\x00\x02\x8d\x03AU\x00\r\x01)\x03%\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x ...
#
# object 5 (stream: False)
# <<
#   /Type /FontDescriptor
#   /FontName /BAAAAA+LiberationSerif
#   /Flags 4
#   /FontBBox [ -543 -303 1277 981 ]
#   /ItalicAngle 0
#   /Ascent 891
#   /Descent -216
#   /CapHeight 981
#   /StemV 80
#   /FontFile2 4 0 R
# >>
#
# object 6 (stream: True)
# <<
#   /Length 281
#   /Filter /FlateDecode
# >>
# b'/CIDInit/ProcSet findresource begin\n12 dict begin\nbegincmap\n/CIDSystemInfo<<\n/Registry (Adobe)\n/Ordering (UCS)\n/Supplement 0\n>> def\n/CMapName/Adobe-Identity-UCS def\n/CMapType 2 def\n1 begincodespacerange\n<00> <FF>\nendcodespacerange\n13 beginbfchar\n<01> <0054>\n<02> <0065>\n<03> <0073>\n<04> <0074>\n<05> <0020>\n<06> <0070>\n<07> <0064>\n<08> <0066>\n<09> <0068>\n<0A> <0069>\n<0B> <006F>\n<0C> <006D>\n<0D> <0078>\nendbfchar\nendcmap\nCMapName currentdict /CMap defineresource pop\nend\nend\n'
#
# object 7 (stream: False)
# <<
#   /Type /Font
#   /Subtype /TrueType
#   /BaseFont /BAAAAA+LiberationSerif
#   /FirstChar 0
#   /LastChar 13
#   /Widths [ 777 610 443 389 277 250 500 500 333 500 277 500 777
#       500 ]
#   /FontDescriptor 5 0 R
#   /ToUnicode 6 0 R
# >>
#
# object 8 (stream: False)
# <<
#   /F1 7 0 R
# >>
#
# object 9 (stream: False)
# <<
#   /Font 8 0 R
#   /ProcSet [ /PDF /Text ]
# >>
#
# object 10 (stream: False)
# <<
#   /Type /Catalog
#   /Pages 3 0 R
#   /OpenAction [ 1 0 R /XYZ null null 0 ]
#   /Lang (nl-NL)
# >>
#
# object 11 (stream: False)
# <<
#   /Creator <FEFF005700720069007400650072>
#   /Producer <FEFF004C0069006200720065004F0066006600690063006500200036002E0034>
#   /CreationDate (D:20231110172204+01'00')
# >>
#
# object 12 (stream: False)
# <<
#   /Type /Font
#   /Subtype /Type1
#   /BaseFont /Courier
#   /Encoding /WinAnsiEncoding
# >>
#
# object 13 (stream: True)
# <<
#   /Length 120
#   /Filter /FlateDecode
# >>
# b'\nq\n79.6 771.393 15.9961 13.2891 re\nh\n1 1 1 RG 1 1 1 rg B\nQ\n\nq\nBT\n1 0 0 1 79.6 777.227 Tm /Courier 8 Tf 0 0 0 RG 0 0 0 rg [<5b315d>]TJ\nET\nQ\n'
